# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobmcasey/KCL_AI_Soc22_Lab2/blob/main/Lab_2_handout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **KCL AI Society 2022/2023: Lab 2** - Computer Vision Object Detection with Deep Learning
# By Jacob Casey (AI Lab Leader)
#
# **Aim**
#
# *   Utilise the power of advanced and state-of-the-art deep learning to detect objects accurately
#
# **Objectives**
#
# *   Perform image processing to first denoise images with opencv
# *   Familiarise yourself with open-source transfer-learning strategies
# *   Leverage the compute of pre-trained models (from research teams at Meta AI, Google, etc.)
# *    Detect fighter jets from aireborne photographs!

# %% [markdown]
# ## Introduction
# ![STILL2-videoSixteenByNine1050.jpg](data:image/jpeg;base64,...)
#
# Object detection is a challenging yet popular computer vision problem, situated at the heart of current AI research. This lab will showcase the pipeline of airborne object-detection, taking a noisy image from a simulated digital sensor, and detecting where in the image the plane is with artifical intelligence.

# %% [markdown]
# ## Task 1 - Transfer learning with huggingface
#
# Visit: https://huggingface.co/ and have a browse. This is a pretty cool open-source resource of loads of pre-implemented AI models that we can use for our own engineering and research! This type of AI practice is called *transfer learning.* Typically when first testing an idea with deep-learning, it is best to use a pre-trained model before spending computational resources training your own AI. Run the following code to just install the libraries needed for using huggingface models with Python

# %%
# Install transformers needed for implementing models from Huggingface.co, & timm for object-detection
# !pip install transformers
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Task 2 - Image processing
#
# Image processing is used in conjunction with computer vision tasks to help us process the image for better object detection (think deblurring, removing noise, making the images brighter).
#
# This is particualrly important when taking imperfect pictures from the real-world from various sensors, often containing motion blur and digital sensor noise. As would be very true in the sense of aerial photography. This is an important step in engineering AI, and data science in general, to make the input data better, instead of optimising the AI detection. In reality, your AI will only ever be as good as the data that it is given.
#
# 1. Your task here is to take the supplied noisy image that contains a type of binary noise called 'salt and pepper' noise and remove the noise using open CV.

# %% [markdown]
# Run the below code to import needed libraries, download the raw file from a simulated plane sensor. You will see that it is very noisy.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import imageio as io
from PIL import Image
import cv2

# !wget "https://github.com/jacobmcasey/KCL_AI_Soc22_Lab2/blob/main/planesensorrawimage.png?raw=true"

# %%
plane_image = io.imread('/content/planesensorrawimage.png?raw=true')
print(plane_image.shape)
imgplot = plt.imshow(plane_image)
# Print noisy image from github repo
# Out:
# (259, 194, 3)

# %%
## Add your code here to denoise an image.

# %% [markdown]
# ##Task 3 - Object Detection with AI

# %% [markdown]
# We will use the detr-resnet-50 model from Facebook as it is a good popular choice that performs well at object detection.
#
# https://huggingface.co/facebook/detr-resnet-50
#
# Copy the code from the above site, changing the input image to the denoised plane image that was done in task (2), to predict objects in the image and where those objects are. You may have to change which detections to show based on the score.

# %%
from transformers import DetrFeatureExtractor, DetrForObjectDetection
import torch
import requests

## Add your code here
